# %% [markdown]
# # Welcome to the challenge notebook
#
# PulseNet has contacted us regarding the performance monitoring of the fine-tuned model we created for them. They want to see how the `training_loss` and `train_mean_token_accuracy` change in each `step` of the model training process.
#
# Your task is to first extract the needed information from the trained model and use line charts to visualize `train_mean_token_accuracy` vs `step` and one line chart for `training_loss` vs `step`.
#
# Follow the instructions in the notebook to complete the challenge task.
#
# Good Luck🍀 <br>
# -Ahmad

# %% [markdown]
# Installing the needed Modules

# %%
# !pip install openai==1.7.2 python-dotenv

# %% [markdown]
# Run the code block below to import the necessary modules and set up the OpenAI API. <br>
# `Hint:` Do not forget to upload the `.env` file

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
import matplotlib.pyplot as plt

load_dotenv(dotenv_path='apikey.env.txt')

APIKEY = os.getenv("APIKEY")
ORGID = os.getenv("ORGID")

client = OpenAI(
  organization= ORGID,
  api_key=APIKEY
)

# %% [markdown]
# Run the code block below to retrieve all the fine-tuned models that you have trained on the OpenAI servers. And select the latest fine-tuning job from the list.

# %%
# Retrieving the list of fine-tuning jobs from the OpenAI client
fine_tuning_jobs = list(client.fine_tuning.jobs.list())

# Selecting the latest fine-tuning job from the list
latest_job = fine_tuning_jobs[-1]
latest_job
# Out:
# FineTuningJob(id='ftjob-5anlwXfCJg4rvoMG0d1yKywS', created_at=1720042477, error=Error(code=None, message=None, param=None), fine_tuned_model='ft:gpt-3.5-turbo-0125:viratec-interactive::9h2049QI', finished_at=1720042819, hyperparameters=Hyperparameters(n_epochs=1, batch_size=1, learning_rate_multiplier=2), model='gpt-3.5-turbo-0125', object='fine_tuning.job', organization_id='org-y4N8JTA9pMOElcFMpsKSUUMv', result_files=['file-csvf71Xsf8nN9gc6DLwUL5pQ'], status='succeeded', trained_tokens=9052, training_file='file-0Cd3kGRwZIBT8P5cmsjawHrr', validation_file=None, user_provided_suffix=None, seed=828539739, estimated_finish=None, integrations=[])

# %% [markdown]
# Now retrieve all the event messages from the retrieved job and put it inside a variable called `events`

# %%
events = client.fine_tuning.jobs.list_events(
    fine_tuning_job_id=latest_job.id, limit=10
)
print(list(events))
# Out:
# [FineTuningJobEvent(id='ftevent-NQLzNSeDWiYN4QeijfDUebWu', created_at=1720042823, level='info', message='The job has successfully completed', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-1moQVzDDL0niZFH6XwzqmjHo', created_at=1720042820, level='info', message='New fine-tuned model created: ft:gpt-3.5-turbo-0125:viratec-interactive::9h2049QI', object='fine_tuning.job.event', data={}, type='message'), FineTuningJobEvent(id='ftevent-oW8ClXaK11WkriGgY2PfLMKz', created_at=1720042815, level='info', message='Step 67/67: training loss=0.23', object='fine_tuning.job.event', data={'step': 67, 'train_loss': 0.22564782202243805, 'total_steps': 67, 'train_mean_token_accuracy': 0.8888888955116272}, type='metrics'), FineTuningJobEvent(id='ftevent-TnUnmJp7QagY2soRUu36Cdo7', created_at=1720042813, level='info', message='Step 66/67: training loss=0.18', object='fine_tuning.job.event', data={'step': 66, 'train_loss': 0.1824834644794464, 'total_steps': 67, 'train_mean_token_accuracy': 0.8888888955116272}, type='metrics'), FineTuningJobEvent(id='ftevent-GC7pqP4Dt5a2wMHgWVRKz4mP', created_at=1720042810, level='info', message='Step 65/67: training loss=0.26', object='fine_tuning.job.event', data={'step': 65, 'train_loss': 0.25697770714759827, 'total_steps': 67, 'train_mean_token_accuracy': 0.9285714030265808}, type='metrics'), FineTuningJobEvent(id='ftevent-A3lWxUHy9uY5SlEhgnH5ZxWO', created_at=1720042808, level='info', message='Step 64/67: training loss=0.04', object='fine_tuning.job.event', data={'step': 64, 'train_loss': 0.03765875846147537, 'total_steps': 67, 'train_mean_token_accuracy': 1.0}, type='metrics'), FineTuningJobEvent(id='ftevent-QsFD9yZ88a6jkwRfYD7cpopB', created_at=1720042806, level='info', message='Step 63/67: training loss=0.11', object='fine_tuning.job.event', data={'step': 63, 'train_loss': 0.11402115970849991, 'total_steps': 67, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'), FineTuningJobEvent(id='ftevent-1dqrcKxcSI84iOOzPVLyH2jU', created_at=1720042803, level='info', message='Step 62/67: training loss=0.22', object='fine_tuning.job.event', data={'step': 62, 'train_loss': 0.21781803667545319, 'total_steps': 67, 'train_mean_token_accuracy': 0.9230769276618958}, type='metrics'), FineTuningJobEvent(id='ftevent-m72EmbAB85vMreOqBDtAePsh', created_at=1720042801, level='info', message='Step 61/67: training loss=0.10', object='fine_tuning.job.event', data={'step': 61, 'train_loss': 0.09674209356307983, 'total_steps': 67, 'train_mean_token_accuracy': 0.9200000166893005}, type='metrics'), FineTuningJobEvent(id='ftevent-sBsDOyo5xlqv7Oj21Io5NUtb', created_at=1720042798, level='info', message='Step 60/67: training loss=0.17', object='fine_tuning.job.event', data={'step': 60, 'train_loss': 0.1676834523677826, 'total_steps': 67, 'train_mean_token_accuracy': 0.9615384340286255}, type='metrics'), FineTuningJobEvent(id='ftevent-VZL9peTxr8qik6a6Uzoa9Tad', created_at=1720042796, level='info', message='Step 59/67: training loss=0.03', object='fine_tuning.job.event', data={'step': 59, 'train_loss': 0.026772765442728996, 'total_steps': 67, 'train_mean_token_accuracy': 1.0}, type='metrics'), FineTuningJobEvent(id='ftevent-Na5SIqRCY4gSzB38h3L4euXw', created_at=1720042794, level='info', message='Step 58/67: training loss=0.08', object='fine_tuning.job.event', data={'step': 58, 'train_loss': 0.08430412411689758, 'total_steps': 67, 'train_mean_token_accuracy': 0.9599999785423279}, type='metrics'), FineTuningJobEvent(id='ftevent-syE1TU6kvqJzgShMrqVimRPg', created_at=1720042791, level='info', message='Step 57/67: training loss=0.20', object='fine_tuning.job.event', data={'step': 57, 'train_loss': 0.19528628885746002, 'total_steps': 67, 'train_mean_token_accuracy': 0.9629629850387573}, type='metrics'), FineTuningJobEvent(id='ftevent-6YKYV0N8YSWAmpboS2ANWU4k', created_at=1720042789, level='info', message='Step 56/67: training loss=0.36', object='fine_tuning.job.event', data={'step': 56, 'train_los ...

# %% [markdown]
# Loop through the `events` and extract the following information from each event object and store them in different lists:
# - steps
# - training_loss
# - train_mean_token_accuracy
#
# `Hint:` Each event object inside the `events` list has a property called data. You can find what you need there!

# %%
# Initialize empty lists to store the extracted information
steps, training_loss, train_mean_token_accuracy = [], [], []

# Loop through each event object in the events list
# Extract and append the step, training loss, and train_mean_token_accuracy from the event object
# write your code here

for e in events:
    if e.data:
        steps.append(e.data['step'])
        training_loss.append(e.data['train_loss'])
        train_mean_token_accuracy.append(e.data['train_mean_token_accuracy'])

# %% [markdown]
# Create a line chart using Matplotlib to visualize how training loss changes over learning steps.

# %%
# write your code here
plt.plot(steps, training_loss)

# %% [markdown]
# Now create a line chart using Matplotlib to visualize how train_mean_token_accuracy changes over learning steps.

# %%
# write your code here
plt.plot(steps, train_mean_token_accuracy)

# %% [markdown]
# 💡 A good model fine-tuning is indicated by a decrease in training loss over the learning steps and an increase in training mean token accuracy over the steps.
#
# Look at the charts you created to assess if your training procedure was effective.
